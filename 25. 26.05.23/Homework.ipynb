# %%
import pandas as pd

# %% [markdown]
# ## Задача 1
#
# Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices
#
# Считать данные с помощью pandas
#
# Вывести на экран первые 5 строк

# %%
df = pd.read_csv("kc-house-data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Задача 1.1
#
# Создать новый признак price_per_sq_lot, который будет содержать стоимость за один кв. метр общей площади

# %%
df['price_per_sq_lot'] = round(df['price']/df['sqft_lot'], 3)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15  price_per_sq_lot
# 0        5650            39.274
# 1        7639            74.289
# 2        8062            18.000
# 3        5000           120.800
# 4        7503            63.119
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Задача 1.2
#
# Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома
#
# Если реновации дома не было, то в новом признаке поставьте 0

# %%
df['delta_renovated'] = df['yr_renovated'] - df['yr_built']
df['delta_renovated'] = df['delta_renovated'].apply(lambda x: 0 if x < 0 else x)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
#    price_per_sq_lot  delta_renovated
# 0            39.274                0
# 1            74.289               40
# 2            18.000                0
# 3           120.800                0
# 4            63.119                0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Задание 1.3
#
# Создайте признаки года продажи, месяца продажи

# %%
df['yr_sell'] = pd.DatetimeIndex(df['date']).year
df['month_sell'] = pd.DatetimeIndex(df['date']).month
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode      lat  \
# 0      5650     1.0           0     0  ...             0    98178  47.5112
# 1      7242     2.0           0     0  ...          1991    98125  47.7210
# 2     10000     1.0           0     0  ...             0    98028  47.7379
# 3      5000     1.0           0     0  ...             0    98136  47.5208
# 4      8080     1.0           0     0  ...             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15  price_per_sq_lot  delta_renovated  \
# 0 -122.257           1340        5650            39.274                0
# 1 -122.319           1690        7639            74.289               40
# 2 -122.233           2720        8062            18.000                0
# 3 -122.393           1360        5000           120.800                0
# 4 -122.045           1800        7503            63.119                0
#
#    yr_sell  month_sell
# 0     2014          10
# 1     2014          12
# 2     2015           2
# 3     2014          12
# 4     2015           2
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Задание 1.4
#
# Удалите признаки date, zipcode, lat, long

# %%
df.drop(columns = ['date', 'zipcode', 'lat', 'long'], inplace = True)
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
#    yr_renovated  sqft_living15  sqft_lot15  price_per_sq_lot  delta_renovated  \
# 0             0           1340        5650            39.274                0
# 1          1991           1690        7639            74.289               40
# 2             0           2720        8062            18.000                0
# 3             0           1360        5000           120.800                0
# 4             0           1800        7503            63.119                0
#
#    yr_sell  month_sell
# 0     2014          10
# 1     2014          12
# 2     2015           2
# 3     2014          12
# 4     2015           2
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Задание 2
#
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
# 'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
# 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
# 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
# 'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
# 1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
# 5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
# 5083000375, 7920100025, 1951600150, 809001400, 339600110,
# 1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
# 8861700030, 3303980210, 7731100066, 8146100580, 825069097,
# 3889100029, 9524100196]
# })

# %%
clients = pd.DataFrame({
    'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295, 
                  939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242, 
                  2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474], 
    'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060, 
                 1189000207, 6821600300, 7137950720, 9510920050, 6131600255, 
                 5428000070, 1788800910, 8100400160, 3123049142, 6306800010, 
                 5083000375, 7920100025, 1951600150, 809001400, 339600110, 
                 1622049154, 1099600250, 8563000110, 2768100205, 3995700435, 
                 8861700030, 3303980210, 7731100066, 8146100580, 825069097, 
                 3889100029, 9524100196]
})

# %% [markdown]
# ### Задание 2.1
#
# Присоедините к таблице clients данные по домам через метод join

# %%
join_table_1 = clients.set_index('house_id').join(df.set_index('id')).reset_index().rename(columns = {'index': 'house_id'})
join_table_1.head()
# Out:
#      house_id  client_id     price  bedrooms  bathrooms  sqft_living  \
# 0   339600110       4809  395000.0         3       2.50         1610
# 1   809001400       3113  925000.0         3       1.00         1630
# 2   825069097       1764  770000.0         3       2.50         2650
# 3  1099600250       2242  260000.0         3       1.75         1710
# 4  1189000207       2308  387000.0         2       2.50         1170
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      3755     2.0           0     0  ...        1610              0
# 1      3200     1.5           0     0  ...        1630              0
# 2     40705     2.0           0     0  ...        2650              0
# 3      6400     1.0           0     0  ...        1240            470
# 4      1394     2.0           0     0  ...        1170              0
#
#    yr_built  yr_renovated  sqft_living15  sqft_lot15  price_per_sq_lot  \
# 0      1987             0           1300        3823           105.193
# 1      1912             0           1710        3600           289.062
# 2      1994             0           2550       42625            18.917
# 3      1976             0           1600        6400            40.625
# 4      2001             0           1250        3136           277.618
#
#    delta_renovated  yr_sell  month_sell
# 0                0     2014           9
# 1                0     2014           9
# 2                0     2014           6
# 3                0     2014          12
# 4                0     2014          10
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Задание 2.2
#
# Присоедините к таблице clients данные по домам через метод merge
#
# Это нужно, чтобы понимать, какие дома покупались клиентами
#
# house_id - это индексы датафрейма с домами

# %%
join_table_2 = clients.merge(df, left_on = 'house_id', right_on = 'id').drop(columns = 'id')
join_table_2.head()
# Out:
#    client_id    house_id     price  bedrooms  bathrooms  sqft_living  \
# 0       1459  8965450190  295000.0         3       2.50         1500
# 1       4684  6823100225  700000.0         4       1.75         1870
# 2       3498  5104540330  679000.0         4       2.50         3680
# 3       3942  2131701075  420000.0         3       1.75         1720
# 4       4535  1522700060  518000.0         4       2.75         2520
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      3060     2.0           0     0  ...        1500              0
# 1      6000     1.0           0     0  ...        1670            200
# 2      7236     2.0           0     0  ...        3680              0
# 3      5000     1.5           0     0  ...        1720              0
# 4     14021     2.0           0     0  ...        2520              0
#
#    yr_built  yr_renovated  sqft_living15  sqft_lot15  price_per_sq_lot  \
# 0      1994             0           2700        7734            96.405
# 1      1949             0           1710        6000           116.667
# 2      2006             0           3310        7180            93.836
# 3      1932          2009           1410        8300            84.000
# 4      1999             0           2330       14007            36.945
#
#    delta_renovated  yr_sell  month_sell
# 0                0     2015           2
# 1                0     2015           4
# 2                0     2015           5
# 3               77     2014          12
# 4                0     2014           6
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Задание 3
#
# Составьте несколько сводных таблиц

# %% [markdown]
# ### Задание 3.1
#
# Найдите среднюю стоимость домов в зависимости от количества спален
#
# Отсортируйте от меньшей стоимости к большей

# %%
df.pivot_table(index = 'bedrooms',
              values = 'price',
              aggfunc = 'mean').round(3).sort_values(by = 'price')
# Out:
#                 price
# bedrooms
# 1          317642.884
# 2          401372.682
# 0          409503.846
# 3          466232.078
# 11         520000.000
# 4          635419.504
# 33         640000.000
# 5          786599.829
# 10         819333.333
# 6          825520.636
# 9          893999.833
# 7          951184.658
# 8         1105076.923

# %% [markdown]
# ### Задание 3.2
#
# Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома

# %%
df.groupby('condition').agg({'price': ['min', 'mean', 'max']}).round(3)
# Out:
#               price
#                 min        mean        max
# condition
# 1           78000.0  334431.667  1500000.0
# 2           80000.0  327287.145  2555000.0
# 3           75000.0  542012.578  7062500.0
# 4           89000.0  521200.390  7700000.0
# 5          110000.0  612418.089  3650000.0

# %% [markdown]
# ### Задание 3.3
#
# Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида

# %%
df.pivot_table(index = 'view',
              columns = 'waterfront',
              values = 'id',
              aggfunc = 'count',
              fill_value = 0)
# Out:
# waterfront      0    1
# view
# 0           19489    0
# 1             331    1
# 2             955    8
# 3             491   19
# 4             184  135

# %% [markdown]
# ### Задание 3.4
#
# Каких домов в зависимости от этажности и количества спален больше?

# %%
df.pivot_table(index = 'bedrooms',
              columns = 'floors',
              values = 'id',
              aggfunc = 'count',
              fill_value = 0)
# Out:
# floors     1.0  1.5   2.0  2.5  3.0  3.5
# bedrooms
# 0            4    0     6    0    2    1
# 1          162   21    12    1    3    0
# 2         1951  182   497    5  123    2
# 3         5455  786  3118   56  405    4
# 4         2383  698  3682   58   61    0
# 5          605  185   775   23   13    0
# 6          104   30   119   14    5    0
# 7            9    7    19    2    1    0
# 8            5    1     6    0    0    1
# 9            0    0     4    2    0    0
# 10           1    0     2    0    0    0
# 11           0    0     1    0    0    0
# 33           1    0     0    0    0    0

# %% [markdown]
# ### Задание 3.5
#
# Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
df.pivot_table(index = 'condition',
              columns = 'grade',
              values = 'price',
              aggfunc = 'mean',
              fill_value = 0).round(3)
# Out:
# grade          1       3       4           5           6           7   \
# condition
# 1          142000       0  150000  280833.333  303813.636  334416.667
# 2               0  280000  179600  206166.667  269483.898  342698.520
# 3               0   75000  210000  246993.460  290651.847  385666.786
# 4               0       0  243905  245299.012  318731.571  412923.073
# 5               0  262000       0  271127.588  310140.859  479667.747
#
# grade              8            9            10           11           12  \
# condition
# 1          932500.000        0.000        0.000        0.000        0.000
# 2          421996.154   715000.000  1752500.000        0.000        0.000
# 3          510102.772   726587.798  1012934.128  1414401.443  2138601.081
# 4          589527.303   889664.525  1176284.590  1839916.429  2467961.538
# 5          736538.049  1123419.897  1735830.364  2238477.273  2290000.000
#
# grade               13
# condition
# 1                0.000
# 2                0.000
# 3          3338636.364
# 4          5750000.000
# 5                0.000
